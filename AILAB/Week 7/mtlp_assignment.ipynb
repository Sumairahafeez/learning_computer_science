# %%
# import libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mlt

# %%
# Generate data
x = np.linspace(0, 10, 100)
y = np.sin(x)

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
fig, ax = plt.subplots()
ax.grid()
ax.plot(x, y,color='blue')
ax.legend(labels="Sign Wave",loc='upper right')

# %%
x = np.linspace(0, 10, 100)
y = np.sin(x)
fig,x = plt.subplots()
ax.p

# %%
import matplotlib.pyplot as plt
import numpy as np

# Generate data
x = np.linspace(0, 10, 100)
y1 = np.sin(x)
y2 = np.cos(x)

# %%
import matplotlib.pyplot as plt

# Sample data
x = [1, 2, 3, 4, 5]
y = [10, 12, 15, 20, 25]

# %%
import matplotlib.pyplot as plt

# Sample data
categories = ['A', 'B', 'C', 'D', 'E']
values = [10, 20, 15, 25, 30]
